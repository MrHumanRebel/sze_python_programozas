# %% [markdown]
# ### 1. feladat [6p]
#
# Készíts programot, amely bekér a felhasználótól két sztringet, majd kiírja a bennük található leghosszabb közös részsztringet! Példa futási eredmény:
# ```
# 1. sztring: András
# 2. sztring: Bandi
# A leghosszabb közös rész: nd
# ```

# %%
def longest_common_substr(s1, s2):
    for i in range(len(s1), 0, -1):
        for j in range(len(s1) - i + 1):
            if s1[j:j + i] in s2:
                return s1[j:j + i]

# %%
longest_common_substr("András", "Bandi")
# Out:
# 'nd'

# %% [markdown]
# ### 2. feladat [8p]
#
# A `birthdays` lista kitalált személyek nevét és születési dátumát tartalmazza. Készíts programot, amely megkeresi, hogy kik állnak életkorban egymáshoz a legközelebb, és hány nap köztük a különbség! A program ne csak a megadott `birthdays` listára működjön, hanem tetszőleges, ugyanilyen formátumú bemenetre is! Feltehetjük, hogy minden név különböző, és legalább két név van megadva.

# %%
birthdays = [
    ('Kovács Andor',   '1999-10-29'),
    ('Kiss Martina',   '2000-02-13'),
    ('Horváth Barna',  '1999-12-05'),
    ('Győri Eszter',   '2000-10-29'),
    ('Nagy Tivadar',   '1999-08-16'),
    ('Tóth Tamara',    '2000-01-30'),
    ('Szakács Sándor', '1999-09-02')
]

# %%
from datetime import datetime

def get_name_of_closest_days_to_each_other(birthdays):   

    birthdays = [(name, datetime.strptime(date, '%Y-%m-%d')) for name, date in birthdays]
    birthdays.sort(key=lambda x: x[1])

    for i in range(len(birthdays) - 1):
        diff = (birthdays[i + 1][1] - birthdays[i][1]).days
        if i == 0:
            closest = diff
            closest_names = birthdays[i][0], birthdays[i + 1][0]
        if diff < closest:
            closest = diff
            closest_names = birthdays[i][0], birthdays[i + 1][0]
    print(f'Életkorban legközelebb állók: {closest_names[0]}, {closest_names[1]}\n {closest} nap köztük a különbség')
    
get_name_of_closest_days_to_each_other(birthdays)
# Out:
# Életkorban legközelebb állók: Tóth Tamara, Kiss Martina
#  14 nap köztük a különbség

# %% [markdown]
# Elvárt futási eredmény:
# ```
#
# Életkorban legközelebb állók: Kiss Martina, Tóth Tamara
# 14 nap köztük a különbség
# ```

# %% [markdown]
# ### 3. feladat [10p]
#
# Az [investments.txt](investments.txt) szövegfájl amerikai cégekbe történő befektetésekről tartalmaz adatokat (a TechCrunch hírportál alapján). Készíts programot, amely kiszámítja és kiírja az alábbi statisztikákat:
#
# - Hány befektetés történt összesen az egyes cégekbe?
# - Melyik cégbe fektették be a legtöbb pénzt?
# - Cégkategóriánként hány dollárt fektettek be összesen?

# %%
filename = '/home/g14/uni/sze_python_programozas/data/investments.txt'

def get_investments(filename):
    with open(filename, 'r') as f:
        # skip the first line
        f.readline()
        lines = f.readlines()
        # read into a list  split by | return the list 
        lines = [line.split('|') for line in lines]    
        # remove the newline character from the last element of each line
        for line in lines:
            line[-1] = line[-1].strip()
            continue
        investments = [] 
        for line in lines:
            investments.append((line[0], line[1], line[2], line[3], line[4], line[5], line[6], line[7], line[8]))   
        return investments
    
def get_companies(investments):
    companies = {}
    for investment in investments:
        company = investment[0]
        if company not in companies:
            companies[company] = 1
        else:
            companies[company] += 1
    for company in companies:
        print(f'{company} => {companies[company]} db befektetés')
    return companies

def get_categories(investments):
    categories = {}
    for investment in investments:
        categorie = investment[2]
        if categorie not in categories:
            categories[categorie] = 1
        else:
            categories[categorie] += 1
    return categories
    
def get_inv_by_company(investments):
    companies = get_companies(investments)
    money = {}    
    for i in range(len(companies)):
        current_company = list(companies.keys())[i]
        for j in range(len(investments)):
            if current_company == investments[j][0]:
                if current_company not in money:
                    money[current_company] = int(investments[j][6])
                else:
                    money[current_company] += int(investments[j][6])
    money = sorted(money.items(), key=lambda x: x[1], reverse=True)
    print('\n')
    print(f'A legtöbb befektetést a {money[0][0]} cégnél tették, összesen {money[0][1]}')
  
def get_inv_by_categ(investments):
    categories = get_categories(investments)
    money = {}    
    for i in range(len(categories)):
        current_categ = list(categories.keys())[i]
        for j in range(len(investments)):
            if current_categ == investments[j][2]:
                if current_categ not in money:
                    money[current_categ] = int(investments[j][6])
                else:
                    money[current_categ] += int(investments[j][6])
    money = sorted(money.items(), key=lambda x: x[1], reverse=True)
    for moni in money:
        print(f'{moni[0]} => {moni[1]}')
             
    
investments = get_investments(filename)

# %%
get_inv_by_company(investments)
# Out:
# LifeLock => 3 db befektetés
# MyCityFaces => 1 db befektetés
# Flypaper => 1 db befektetés
# Infusionsoft => 1 db befektetés
# gAuto => 1 db befektetés
# ChosenList.com => 2 db befektetés
# Digg => 2 db befektetés
# Facebook => 7 db befektetés
# Photobucket => 2 db befektetés
# Omnidrive => 1 db befektetés
# Geni => 2 db befektetés
# Twitter => 2 db befektetés
# StumbleUpon => 1 db befektetés
# Gizmoz => 2 db befektetés
# Scribd => 3 db befektetés
# Slacker => 2 db befektetés
# Lala => 1 db befektetés
# Plaxo => 4 db befektetés
# Powerset => 1 db befektetés
# Technorati => 4 db befektetés
# Mahalo => 2 db befektetés
# Kyte => 3 db befektetés
# Veoh => 4 db befektetés
# Jingle Networks => 5 db befektetés
# Ning => 2 db befektetés
# JotSpot => 1 db befektetés
# Mercora => 1 db befektetés
# Wesabe => 2 db befektetés
# Jangl => 1 db befektetés
# Hyphen 8 => 1 db befektetés
# Prosper => 3 db befektetés
# Google => 1 db befektetés
# Jajah => 3 db befektetés
# YouTube => 2 db befektetés
# Ustream => 2 db befektetés
# GizmoProject => 1 db befektetés
# Adap.tv => 1 db befektetés
# Topix => 1 db befektetés
# Revision3 => 2 db befektetés
# Aggregate Knowledge => 2 db befektetés
# Sugar Inc => 2 db befektetés
# Zing => 1 db befektetés
# CriticalMetrics => 1 db befektetés
# Spock => 1 db befektetés
# Wize => 1 db befektetés
# SodaHead => 2 db befektetés
# CastTV => 1 db befektetés
# BuzzNet => 2 db befektetés
# Funny Or Die => 1 db befektetés
# Sphere => 2 db befektetés
# MeeVee => 4 db befektetés
# Mashery => 1 db befektetés
# Yelp => 4 db befektetés
# Spotplex => 1 db befektetés
# Coghead => 2 db befektetés
# Zooomr => 1 db befektetés
# SideStep => 4 db befektetés
# RockYou => 4 db befektetés
# Pageflakes => 1 db befektetés
# Swivel => 2 db befektetés
# Slide => 2 db befektetés
# Bebo => 1 db befektetés
# freebase => 2 db befektetés
# Metaweb Technologies => 1 db befektetés
# Glam Media => 5 db befektetés
# TheFind => 3 db befektetés
# Zazzle => 2 db befektetés
# Dogster => 1 db befektetés
# Pandora => 3 db befektetés
# Cafepress => 3 db befektetés
# pbwiki => 2 db befektetés
# AdBrite => 3 db befektetés
# Loomia => 2 db befektetés
# Meebo => 3 db befektetés
# Eventbrite => 1 db befektetés
# LinkedIn => 4 db befektetés
# FlickIM => 1 db befektetés
# Terabitz => 1 db befektetés
# Healthline => 2 db befektetés
# Box.net => 2 db befektetés
# Conduit => 2 db befektetés
# Edgeio => 1 db befektetés
# Spot Runner => 3 db befektetés
# Kaboodle => 3 db befektetés
# Giga Omni Media => 1 db befektetés
# Visible Path => 2 db befektetés
# Wink => 1 db befektetés
# seesmic => 2 db befektetés
# Zvents => 2 db befektetés
# Eventful => 2 db befektetés
# Oodle => 2 db befektetés
# oDesk => 3 db befektetés
# SimplyHired => 2 db befektetés
# ooma => 2 db befektetés
# GoingOn => 1 db befektetés
# Flixster => 2 db befektetés
# Piczo => 1 db befektetés
# Socialtext => 3 db befektetés
# PowerReview => 2 db befektetés
# hi5 => 2 db befektetés
# Tagged => 3 db befektetés
# Jaxtr => 3 db befektetés
# Me => 1 db befektetés
# introNetworks => 1 db befektetés
# Leverage Software => 1 db befektetés
# Lithium Technologies => 2 db befektetés
# Genius => 3 db befektetés
# Respectance => 2 db befektetés
# Curse => 1 db befektetés
# LicketyShip => 1 db befektetés
# Grockit => 2 db befektetés
# PeerMe => 1 db befektetés
# Kiptronic => 3 db befektetés
# Vuze => 2 db befektetés
# Phonezoo => 2 db befektetés
# Droplet Technology => 1 db befektetés
# PodTech => 2 db befektetés
# Crackle => 1 db befektetés
# Reddit => 1 db befektetés
# Wikia => 2 db befektetés
# Retrevo => 3 db befektetés
# Buxfer => 2 db befektetés
# YouSendIt => 3 db befektetés
# Tangler => 1 db befektetés
# obopay => 4 db befektetés
# PayPal => 3 db befektetés
# TalkPlus => 1 db befektetés
# Vudu => 1 db befektetés
# Insider Pages => 1 db befektetés
# Snapfish => 2 db befektetés
# Affinity Circles => 3 db befektetés
# IMVU => 1 db befektetés
# Nirvanix => 1 db befektetés
# Habit Industries => 1 db befektetés
# Gaia => 3 db befektetés
# GreatCall => 1 db befektetés
# Revver => 2 db befektetés
# Metacafe => 2 db befektetés
# Flock => 3 db befektetés
# VMIX Media => 2 db befektetés
# Kontera => 2 db befektetés
# Tokbox => 2 db befektetés
# Six Apart => 3 db befektetés
# Weebly => 1 db befektetés
# Synthasite => 1 db befektetés
# BitTorrent => 2 db befektetés
# Kongregate => 3 db befektetés
# DanceJam => 2 db befektetés
# Fathom Online => 1 db befektetés
# Zivity => 2 db befektetés
# BlueLithium => 1 db befektetés
# eXpresso => 1 db befektetés
# Doostang => 1 db befektetés
# Docstoc => 2 db befektetés
# Mevio => 3 db befektetés
# PureVideo Networks => 2 db befektetés
# FilmLoop => 1 db befektetés
# BitPass => 2 db befektetés
# Art.com => 1 db befektetés
# Atom Shockwave => 1 db befektetés
# CinemaNow => 1 db befektetés
# Digital Chocolate => 2 db befektetés
# eHarmony => 2 db befektetés
# Friendster => 4 db befektetés
# Greystripe => 1 db befektetés
# Sling Media => 2 db befektetés
# Trulia => 4 db befektetés
# Lending Club => 2 db befektetés
# tubemogul => 1 db befektetés
# Gemini => 2 db befektetés
# Multiverse => 2 db befektetés
# LimeLife => 3 db befektetés
# OpenTable => 3 db befektetés
# RooftopComedy => 1 db befektetés
# Federated Media => 2 db befektetés
# Delivery Agent => 3 db befektetés
# Reunion => 1 db befektetés
# Mixercast => 2 db befektetés
# mTraks => 1 db befektetés
# Xora => 3 db befektetés
# Ooyala => 1 db befektetés
# SayNow => 1 db befektetés
# Crunchyroll => 1 db befektetés
# CircleUp => 1 db befektetés
# PixSense => 2 db befektetés
# Danal => 1 db befektetés
# hulu => 1 db befektetés
# OurStory => 1 db befektetés
# Specificmedia => 2 db befektetés
# AdMob => 1 db befektetés
# MySQL => 2 db befektetés
# Attributor => 3 db befektetés
# Social Media => 2 db befektetés
# Demand Media => 4 db befektetés
# TripIt => 1 db befektetés
# PubMatic => 1 db befektetés
# Mint => 3 db befektetés
# app2you => 2 db befektetés
# YourStreet => 1 db befektetés
# Tagworld => 2 db befektetés
# RotoHog => 1 db befektetés
# ThisNext => 2 db befektetés
# ChessPark => 1 db befektetés
# Break => 1 db befektetés
# MuseStorm => 1 db befektetés
# Media Machines => 1 db befektetés
# Ciihui => 2 db befektetés
# Aliph => 1 db befektetés
# mEgo => 2 db befektetés
# Realius => 1 db befektetés
# Xobni => 3 db befektetés
# Spoke => 2 db befektetés
# FixYa => 2 db befektetés
# Mozilla => 1 db befektetés
# BrightQube => 1 db befektetés
# BuzzDash => 1 db befektetés
# Urban Mapping => 1 db befektetés
# Consorte Media => 1 db befektetés
# ffwd => 1 db befektetés
# Get Satisfaction => 1 db befektetés
# RingCentral => 2 db befektetés
# 3Jam => 1 db befektetés
# PlaySpan => 1 db befektetés
# Grouply => 3 db befektetés
# Graspr => 1 db befektetés
# Zannel => 1 db befektetés
# deca.tv => 1 db befektetés
# Zimbra => 1 db befektetés
# FriendFeed => 1 db befektetés
# Rupture => 1 db befektetés
# JibJab => 1 db befektetés
# Rubicon Project => 3 db befektetés
# SnapLayout => 1 db befektetés
# Confabb => 1 db befektetés
# UpTake => 1 db befektetés
# 23andMe => 1 db befektetés
# YuMe => 1 db befektetés
# Mochi Media => 2 db befektetés
# Blurb => 1 db befektetés
# WeatherBill => 1 db befektetés
# Automattic => 2 db befektetés
# Radar Networks => 2 db befektetés
# Veodia => 1 db befektetés
# EchoSign => 1 db befektetés
# Rollbase => 1 db befektetés
# Predictify => 1 db befektetés
# TrialPay => 1 db befektetés
# Socializr => 1 db befektetés
# Eurekster => 2 db befektetés
# Gydget => 1 db befektetés
# PicksPal => 1 db befektetés
# Gigya => 2 db befektetés
# Songbird => 1 db befektetés
# Guardian Analytics => 1 db befektetés
# Fora.TV => 1 db befektetés
# Disqus => 1 db befektetés
# SezWho => 1 db befektetés
# YieldBuild => 1 db befektetés
# Akimbo => 4 db befektetés
# Laszlo Systems => 2 db befektetés
# BrightRoll => 1 db befektetés
# MerchantCircle => 1 db befektetés
# Minekey => 1 db befektetés
# Booking Angel => 1 db befektetés
# Loopt => 2 db befektetés
# Fix8 => 2 db befektetés
# MyBuys => 2 db befektetés
# BlackArrow => 2 db befektetés
# Peerflix => 2 db befektetés
# fatdoor => 3 db befektetés
# Verimatrix => 2 db befektetés
# Billeo => 2 db befektetés
# Caring.com => 1 db befektetés
# Ask.com => 1 db befektetés
# Project Playlist => 1 db befektetés
# Blowtorch => 1 db befektetés
# GameLayers => 1 db befektetés
# MoGreet => 2 db befektetés
# YourTrumanShow => 1 db befektetés
# Apprema => 1 db befektetés
# TrustedID => 2 db befektetés
# Seeqpod => 1 db befektetés
# Quantenna => 1 db befektetés
# Qwaq => 1 db befektetés
# uber => 1 db befektetés
# CashView => 1 db befektetés
# CrossLoop => 1 db befektetés
# Dapper => 1 db befektetés
# Anchor Intelligence => 2 db befektetés
# EdgeCast => 2 db befektetés
# Kosmix => 1 db befektetés
# GoodReads => 1 db befektetés
# Ribbit => 2 db befektetés
# Jobvite => 1 db befektetés
# Juice Wireless => 5 db befektetés
# Qik => 1 db befektetés
# PlayFirst => 2 db befektetés
# Mobissimo => 1 db befektetés
# Chumby => 2 db befektetés
# UGOBE => 1 db befektetés
# Ausra => 1 db befektetés
# Causes => 2 db befektetés
# Nanosolar => 2 db befektetés
# Shozu => 2 db befektetés
# Tesla Motors => 5 db befektetés
# Bunchball => 2 db befektetés
# Pinger => 1 db befektetés
# Hooja => 1 db befektetés
# TravelMuse => 1 db befektetés
# Cooking.com => 4 db befektetés
# Meraki => 2 db befektetés
# SugarCRM => 4 db befektetés
# Pudding Media => 1 db befektetés
# 4HomeMedia => 1 db befektetés
# Pageonce => 1 db befektetés
# bluepulse => 1 db befektetés
# Mogad => 1 db befektetés
# DeviceVM => 2 db befektetés
# Outspark => 2 db befektetés
# Engine Yard => 2 db befektetés
# PLYmedia => 2 db befektetés
# fabrik => 4 db befektetés
# Widgetbox => 3 db befektetés
# RazorGator => 2 db befektetés
# OverSee => 2 db befektetés
# Zynga => 2 db befektetés
# Smaato => 1 db befektetés
# Credit Karma => 1 db befektetés
# Greenplum => 4 db befektetés
# Amobee => 2 db befektetés
# WebMynd => 1 db befektetés
# Current Media => 1 db befektetés
# Heroku => 2 db befektetés
# Lookery => 1 db befektetés
# Mill River Labs => 1 db befektetés
# Grouptivity => 1 db befektetés
# Aductions => 1 db befektetés
# VentureBeat => 1 db befektetés
# Collarity => 1 db befektetés
# RocketOn => 1 db befektetés
# What They Like => 1 db befektetés
# GumGum => 2 db befektetés
# Snap Technologies => 1 db befektetés
# TwoFish => 1 db befektetés
# Three Rings => 1 db befektetés
# Smalltown => 1 db befektetés
# Sparkplay Media => 1 db befektetés
# MOG => 2 db befektetés
# Social Gaming Network => 1 db befektetés
# Danger => 3 db befektetés
# Coverity => 1 db befektetés
# GenieTown => 1 db befektetés
# Redux => 2 db befektetés
# Evernote => 2 db befektetés
# Numobiq => 1 db befektetés
# GoldSpot Media => 1 db befektetés
# Mobixell => 1 db befektetés
# Ad Infuse => 2 db befektetés
# SendMe => 2 db befektetés
# Tiny Pictures => 2 db befektetés
# flurry => 1 db befektetés
# Teneros => 4 db befektetés
# PhotoCrank => 1 db befektetés
# Yodlee => 1 db befektetés
# SlideRocket => 1 db befektetés
# Surf Canyon => 2 db befektetés
# Central Desktop => 1 db befektetés
# OpenDNS => 1 db befektetés
# Coveo => 1 db befektetés
# Vizu => 2 db befektetés
# Taltopia => 1 db befektetés
# Kapow Technologies => 1 db befektetés
# ProgrammerMeetDesigner.com => 1 db befektetés
# LiveOps => 2 db befektetés
# Clickpass => 1 db befektetés
# SearchMe => 5 db befektetés
# AccountNow => 1 db befektetés
# DailyStrength => 1 db befektetés
# PopularMedia => 2 db befektetés
# Clarizen => 1 db befektetés
# SellPoint => 1 db befektetés
# LiveDeal => 1 db befektetés
# NeoEdge Networks => 1 db befektetés
# Zuora => 1 db befektetés
# Jivox => 2 db befektetés
# kwiry => 1 db befektetés
# SupplyFrame => 1 db befektetés
# InMage Systems => 1 db befektetés
# Authenticlick => 1 db befektetés
# Interneer => 2 db befektetés
# Handipoints => 2 db befektetés
# Adconion Media Group => 1 db befektetés
# SlideShare => 1 db befektetés
# Intent => 1 db befektetés
# Wikimedia Foundation => 1 db befektetés
# Clearwell Systems => 1 db befektetés
# Become => 2 db befektetés
# Bubble Motion => 2 db befektetés
# Perfect Market => 1 db befektetés
# Glassdoor => 1 db befektetés
# Support Space => 1 db befektetés
# Xoopit => 2 db befektetés
# Reality Digital => 2 db befektetés
# Cloud9 Analytics => 1 db befektetés
# Netcipia => 1 db befektetés
# iControl => 2 db befektetés
# Frengo => 2 db befektetés
# mBlox => 4 db befektetés
# eSolar => 2 db befektetés
# Marin Software => 2 db befektetés
# SiBEAM => 4 db befektetés
# Lumos Labs => 2 db befektetés
# iRise => 1 db befektetés
# richrelevance => 1 db befektetés
# Labmeeting => 1 db befektetés
# Shopflick => 2 db befektetés
# TurnHere => 2 db befektetés
# Coupa => 2 db befektetés
# SquareTrade => 2 db befektetés
# V-Enable => 2 db befektetés
# Aeria => 1 db befektetés
# Heysan => 1 db befektetés
# Memeo => 1 db befektetés
# imageshack => 1 db befektetés
# CellSpin => 1 db befektetés
# Remixation => 1 db befektetés
# The Auteurs => 1 db befektetés
# Modern Feed => 1 db befektetés
# GROU.PS => 1 db befektetés
# Triggit => 2 db befektetés
# Serious Business => 1 db befektetés
# Presdo => 1 db befektetés
# Nile Guide => 1 db befektetés
# Adify => 2 db befektetés
# Invensense => 1 db befektetés
# Center'd => 3 db befektetés
# New Relic => 1 db befektetés
# Gridstone Research => 1 db befektetés
# FusionOps => 1 db befektetés
# MarketLive => 1 db befektetés
# SnapLogic => 1 db befektetés
# Boardwalktech => 1 db befektetés
# Rosum => 1 db befektetés
# Dilithium Networks => 3 db befektetés
# Experience Project => 1 db befektetés
# Mozes => 2 db befektetés
# rVita => 1 db befektetés
# Mefeedia => 1 db befektetés
# Wavemaker Software => 1 db befektetés
# VirtualLogix => 1 db befektetés
# Fonemesh => 2 db befektetés
# Cognition Technologies => 1 db befektetés
# Sometrics => 1 db befektetés
# SocialVibe => 1 db befektetés
# deviantART => 1 db befektetés
# MyThings => 1 db befektetés
# mywaves => 1 db befektetés
# litescape => 1 db befektetés
# Parascale => 1 db befektetés
# Row44 => 1 db befektetés
# JellyCloud => 1 db befektetés
# Aster Data Systems => 2 db befektetés
# Pixim => 3 db befektetés
# Funambol => 4 db befektetés
# Moblyng => 2 db befektetés
# Zecter => 1 db befektetés
# Votigo => 1 db befektetés
# Zinio => 1 db befektetés
# Dreamfactory => 1 db befektetés
# GreenNote => 1 db befektetés
# Skyfire => 2 db befektetés
# eduFire => 1 db befektetés
# B-hive Networks => 1 db befektetés
# NeuroVigil => 1 db befektetés
# Sylantro => 3 db befektetés
# TeleFlip => 1 db befektetés
# Vidshadow => 1 db befektetés
# Jigsaw => 3 db befektetés
# Ozmo Devices => 1 db befektetés
# Cooliris => 1 db befektetés
# Gamook => 1 db befektetés
# Vindicia => 1 db befektetés
# Dizzywood => 1 db befektetés
# Limbo => 1 db befektetés
# StartForce => 1 db befektetés
# coolearth => 2 db befektetés
# Yield Software => 1 db befektetés
# Tapulous => 1 db befektetés
# Codefast => 1 db befektetés
# Hyperic => 1 db befektetés
# iPling :)) => 1 db befektetés
# Intacct => 2 db befektetés
# Vivaty => 1 db befektetés
# Aurora Biofuels => 1 db befektetés
# AllBusiness.com => 2 db befektetés
# InsideView => 1 db befektetés
# Clickability => 1 db befektetés
# Keibi Technologies => 1 db befektetés
# RoboDynamics => 2 db befektetés
# ImageSpan => 1 db befektetés
# Solarflare => 1 db befektetés
# Clupedia => 1 db befektetés
# Zigabid => 2 db befektetés
# InThrMa => 1 db befektetés
# Fluid Entertainment => 1 db befektetés
# Unisfair => 1 db befektetés
# ON24 => 1 db befektetés
# trueAnthem => 1 db befektetés
# Colizer => 1 db befektetés
# Coremetrics => 2 db befektetés
# Appirio => 2 db befektetés
# samfind => 1 db befektetés
# Eye-Fi => 1 db befektetés
# ResponseLogix => 1 db befektetés
# Qumu => 1 db befektetés
# CarbonFlow => 1 db befektetés
# Allvoices => 1 db befektetés
# Moxsie => 1 db befektetés
# Service-now.com => 2 db befektetés
# Anvato => 1 db befektetés
# Vantage Media => 1 db befektetés
# Entone Technologies => 2 db befektetés
# 750 Industries => 1 db befektetés
# Plastic Logic => 5 db befektetés
# Paymo => 1 db befektetés
# SkyGrid => 1 db befektetés
# Intense Debate => 1 db befektetés
# Associated Content => 2 db befektetés
# madKast => 2 db befektetés
# EventVue => 2 db befektetés
# Socialthing! => 2 db befektetés
# J Squared Media => 1 db befektetés
# Search to Phone => 1 db befektetés
# Filtrbox => 2 db befektetés
# Brightkite => 2 db befektetés
# NewsGator => 3 db befektetés
# Me.dium => 1 db befektetés
# Buzzwire => 1 db befektetés
# HiveLive => 2 db befektetés
# XAware => 2 db befektetés
# Lijit => 2 db befektetés
# hubbuzz => 1 db befektetés
# Gnip => 1 db befektetés
# Rally Software => 2 db befektetés
# Symplified => 1 db befektetés
# Indeed => 1 db befektetés
# Geezeo => 1 db befektetés
# Entrecard => 2 db befektetés
# AmericanTowns.com => 2 db befektetés
# Kayak => 3 db befektetés
# GoCrossCampus => 1 db befektetés
# Health Plan One => 1 db befektetés
# Your Survival => 1 db befektetés
# Media Lantern => 1 db befektetés
# GridPoint => 4 db befektetés
# HotPads => 1 db befektetés
# LaunchBox => 1 db befektetés
# Cogent => 1 db befektetés
# SwapDrive => 2 db befektetés
# Searchles => 1 db befektetés
# PayPerPost => 2 db befektetés
# Affinity Internet => 2 db befektetés
# Multiply => 3 db befektetés
# Revolution Money => 1 db befektetés
# Batanga => 2 db befektetés
# divorce360 => 1 db befektetés
# Infinity Box => 2 db befektetés
# MOLI => 1 db befektetés
# Global Roaming => 2 db befektetés
# Slingpage => 1 db befektetés
# WrapMail => 1 db befektetés
# eJamming => 1 db befektetés
# Lehigh Technologies => 1 db befektetés
# TournEase => 2 db befektetés
# Vitrue => 2 db befektetés
# Screaming Sports => 1 db befektetés
# beRecruited => 1 db befektetés
# MFG => 3 db befektetés
# Scintella Solutions => 1 db befektetés
# ScribeStorm => 1 db befektetés
# Balihoo => 2 db befektetés
# Info => 1 db befektetés
# FeedBurner => 2 db befektetés
# Viewpoints => 1 db befektetés
# GrubHub => 1 db befektetés
# TicketsNow => 1 db befektetés
# The Point => 2 db befektetés
# Inkling => 1 db befektetés
# crowdSPRING => 1 db befektetés
# Ifbyphone => 1 db befektetés
# Fave Media => 1 db befektetés
# Accertify => 1 db befektetés
# Firefly Energy => 3 db befektetés
# SAVO => 1 db befektetés
# ChaCha => 2 db befektetés
# Better World Books => 1 db befektetés
# Compendium Blogware => 2 db befektetés
# Instagarage => 1 db befektetés
# iSkoot => 2 db befektetés
# Gotuit Media => 2 db befektetés
# Carbonite => 4 db befektetés
# ScanScout => 2 db befektetés
# Going => 1 db befektetés
# Brightcove => 5 db befektetés
# PermissionTV => 1 db befektetés
# Bountii => 1 db befektetés
# Conduit Labs => 1 db befektetés
# ZoomInfo => 2 db befektetés
# Vlingo => 1 db befektetés
# Vtap => 1 db befektetés
# MocoSpace => 1 db befektetés
# Quattro Wireless => 2 db befektetés
# Care.com => 1 db befektetés
# OnForce => 2 db befektetés
# RatePoint => 1 db befektetés
# UpDown => 1 db befektetés
# Eons => 2 db befektetés
# GamerDNA => 1 db befektetés
# Mix & Meet => 1 db befektetés
# Sermo => 3 db befektetés
# WorkLight => 2 db befektetés
# MatchMine => 1 db befektetés
# CondoDomain => 1 db befektetés
# uTest => 1 db befektetés
# Compete => 2 db befektetés
# Azuki Systems => 1 db befektetés
# Acinion => 2 db befektetés
# xkoto => 1 db befektetés
# HubSpot => 3 db befektetés
# Utterz => 1 db befektetés
# Intronis => 1 db befektetés
# Acquia => 1 db befektetés
# A123Systems => 3 db befektetés
# Boston Power => 3 db befektetés
# Visible Measures => 3 db befektetés
# Endeca => 4 db befektetés
# ChoiceStream => 4 db befektetés
# YouCastr => 1 db befektetés
# JackPot Rewards => 1 db befektetés
# Mzinga => 1 db befektetés
# Dimdim => 2 db befektetés
# utoopia => 1 db befektetés
# Retail Convergence => 1 db befektetés
# Frame Media => 2 db befektetés
# Turbine => 2 db befektetés
# Zeer => 1 db befektetés
# SimpleTuition => 2 db befektetés
# Sirtris Pharmaceuticals => 3 db befektetés
# Good Data => 1 db befektetés
# Navic Networks => 3 db befektetés
# Pivot => 2 db befektetés
# Optaros => 3 db befektetés
# Astaro => 2 db befektetés
# Pangea Media => 1 db befektetés
# Posterous => 1 db befektetés
# Spire => 1 db befektetés
# neoSaej => 1 db befektetés
# GenArts => 1 db befektetés
# OrderMotion => 1 db befektetés
# HAM-IT => 1 db befektetés
# Freewebs => 1 db befektetés
# MPTrax => 1 db befektetés
# JackBe => 1 db befektetés
# ZeniMax => 2 db befektetés
# Intelliworks => 3 db befektetés
# HEXIO => 1 db befektetés
# Foneshow => 2 db befektetés
# Zattoo => 1 db befektetés
# LoudClick => 1 db befektetés
# Agilis Systems => 1 db befektetés
# International Liars Poker Association => 1 db befektetés
# ChannelAdvisor => 3 db befektetés
# Yap => 2 db befektetés
# PrepChamps => 1 db befektetés
# BrightDoor Systems => 1 db befektetés
# DriftToIt => 1 db befektetés
# rPath => 3 db befektetés
# Ntractive => 1 db befektetés
# Bill Me Later => 1 db befektetés
# AdaptiveBlue => 1 db befektetés
# Phanfare => 2 db befektetés
# EnterpriseDB => 3 db befektetés
# Neocleus => 1 db befektetés
# Datapipe => 1 db befektetés
# Switch2Health => 1 db befektetés
# Voltaix => 1 db befektetés
# SpaBoom => 2 db befektetés
# Novint => 1 db befektetés
# MeetMoi => 1 db befektetés
# Meetup => 3 db befektetés
# Mogulus => 3 db befektetés
# Pando => 2 db befektetés
# Outside.in => 3 db befektetés
# SelectMinds => 1 db befektetés
# Veotag => 1 db befektetés
# KIT digital => 2 db befektetés
# ContextWeb => 3 db befektetés
# Datran Media => 1 db befektetés
# Eyeblaster => 2 db befektetés
# Covestor => 2 db befektetés
# Global Grind => 1 db befektetés
# Heavy.com => 1 db befektetés
# SpiralFrog => 1 db befektetés
# Broadband Enterprises => 1 db befektetés
# Thumbplay => 1 db befektetés
# Waterfront Media => 4 db befektetés
# Tutor => 1 db befektetés
# Daylife => 1 db befektetés
# Teach The People => 1 db befektetés
# OrganizedWisdom => 1 db befektetés
# Snooth => 2 db befektetés
# 5min => 2 db befektetés
# Kaltura => 1 db befektetés
# Mimeo => 1 db befektetés
# RayV => 1 db befektetés
# Tumblr => 1 db befektetés
# Payoneer => 1 db befektetés
# eXelate => 1 db befektetés
# Quigo => 1 db befektetés
# Peer39 => 3 db befektetés
# Rebel Monkey => 1 db befektetés
# Answers Corporation => 5 db befektetés
# SeeToo => 1 db befektetés
# drop.io => 2 db befektetés
# Motionbox => 2 db befektetés
# DGP Labs => 1 db befektetés
# Ideeli => 1 db befektetés
# Live Gamer => 1 db befektetés
# WeShow => 1 db befektetés
# Etsy => 4 db befektetés
# PhoneTag => 3 db befektetés
# Tremor Media => 2 db befektetés
# YooNew => 1 db befektetés
# Fifth Generation Systems => 2 db befektetés
# IGA Worldwide => 3 db befektetés
# TheLadders => 1 db befektetés
# Adotube => 2 db befektetés
# Kluster => 1 db befektetés
# Blog Talk Radio => 1 db befektetés
# Pingg => 2 db befektetés
# Outbrain => 2 db befektetés
# Mochila => 1 db befektetés
# OLX => 2 db befektetés
# Boonty => 1 db befektetés
# Tripology => 1 db befektetés
# The Feedroom => 1 db befektetés
# Next New Networks => 2 db befektetés
# RiverWired => 1 db befektetés
# Fynanz => 1 db befektetés
# Digital Railroad => 2 db befektetés
# Undertone Networks => 1 db befektetés
# Someecards => 1 db befektetés
# Trunkt => 1 db befektetés
# Cutcaster => 1 db befektetés
# Visible World => 2 db befektetés
# Mad Mimi => 1 db befektetés
# Social Median => 1 db befektetés
# Scanbuy => 2 db befektetés
# Pontiflex => 1 db befektetés
# CHIC.TV => 1 db befektetés
# ExpertFlyer => 1 db befektetés
# x+1 => 1 db befektetés
# Media6¡ => 1 db befektetés
# Knewton => 1 db befektetés
# Sense Networks => 1 db befektetés
# TargetSpot => 1 db befektetés
# BountyJobs => 1 db befektetés
# vbs tv => 1 db befektetés
# Instinctiv => 1 db befektetés
# VISUALPLANT => 1 db befektetés
# XunLight => 1 db befektetés
# Strands => 3 db befektetés
# Jive Software => 1 db befektetés
# Platial => 2 db befektetés
# GarageGames => 1 db befektetés
# iovation => 1 db befektetés
# InGrid => 4 db befektetés
# Sleep.FM => 1 db befektetés
# Boomi => 1 db befektetés
# Styky => 1 db befektetés
# TotalTakeout => 1 db befektetés
# QponDirect => 1 db befektetés
# EnergyWeb Solutions => 1 db befektetés
# Aria Systems => 1 db befektetés
# Viv’simo => 5 db befektetés
# ShowClix => 2 db befektetés
# BioWizard => 1 db befektetés
# TicketLeap => 1 db befektetés
# Tizra => 1 db befektetés
# Quickoffice => 3 db befektetés
# Thoof => 1 db befektetés
# Bazaarvoice => 3 db befektetés
# Small World Labs => 1 db befektetés
# Pluck => 2 db befektetés
# Spiceworks => 1 db befektetés
# SpendView => 1 db befektetés
# Shangby => 1 db befektetés
# On Networks => 2 db befektetés
# CareFlash => 1 db befektetés
# HelioVolt => 1 db befektetés
# Challenge Games => 1 db befektetés
# Woot => 1 db befektetés
# Mumboe => 1 db befektetés
# BreakingPoint Systems => 1 db befektetés
# FameCast => 1 db befektetés
# Click Forensics => 2 db befektetés
# GodTube => 1 db befektetés
# iBiz Software => 1 db befektetés
# Cosential => 1 db befektetés
# JAD Tech Consulting => 1 db befektetés
# Mozy => 2 db befektetés
# Ancestry.com => 1 db befektetés
# Move Networks => 3 db befektetés
# World Vital Records => 1 db befektetés
# Bungee Labs => 1 db befektetés
# Footnote => 1 db befektetés
# mediaFORGE => 1 db befektetés
# TeamStreamz => 1 db befektetés
# Exinda => 1 db befektetés
# Clearspring => 4 db befektetés
# Avail Media => 2 db befektetés
# FortiusOne => 1 db befektetés
# Mixx => 2 db befektetés
# Jobfox => 3 db befektetés
# HealthCentral => 1 db befektetés
# comScore => 2 db befektetés
# VisualCV => 1 db befektetés
# ShoutWire => 1 db befektetés
# Parature => 2 db befektetés
# Loladex => 1 db befektetés
# Appian => 1 db befektetés
# Fortisphere => 1 db befektetés
# Wetpaint => 3 db befektetés
# Jobster => 4 db befektetés
# Yapta => 2 db befektetés
# Farecast => 3 db befektetés
# Haute Secure => 1 db befektetés
# Newsvine => 1 db befektetés
# iLike => 2 db befektetés
# Redfin => 3 db befektetés
# Action Engine => 5 db befektetés
# Wishpot => 1 db befektetés
# PayScale => 3 db befektetés
# BuddyTV => 3 db befektetés
# Judys Book => 2 db befektetés
# Sampa => 2 db befektetés
# Zango => 1 db befektetés
# Cdigix => 1 db befektetés
# Ripl => 1 db befektetés
# EyeJot => 2 db befektetés
# FlowPlay => 2 db befektetés
# SmartSheet => 1 db befektetés
# Visible Technologies => 2 db befektetés
# Zillow => 3 db befektetés
# SEOMoz => 1 db befektetés
# DocuSign => 2 db befektetés
# AdReady => 1 db befektetés
# Treemo => 1 db befektetés
# GridNetworks => 1 db befektetés
# Pelago => 2 db befektetés
# Blist => 1 db befektetés
# RealSelf => 1 db befektetés
# RescueTime => 1 db befektetés
# Zoji => 1 db befektetés
# Snapvine => 2 db befektetés
# Jott => 1 db befektetés
# Earth Class Mail => 2 db befektetés
# Smilebox => 2 db befektetés
# Fyreball => 1 db befektetés
# Delve Networks => 2 db befektetés
# LiveMocha => 1 db befektetés
# Mercent Corporation => 1 db befektetés
# CleverSet => 3 db befektetés
# LiquidPlanner => 1 db befektetés
# Limeade => 1 db befektetés
# Yodio => 1 db befektetés
# Tastemakers => 1 db befektetés
# WhitePages.com => 1 db befektetés
# RevenueScience => 1 db befektetés
# GotVoice => 1 db befektetés
# CarDomain Network => 1 db befektetés
# mpire => 2 db befektetés
# TeachStreet => 1 db befektetés
# Estately => 1 db befektetés
# Infinia => 2 db befektetés
# M:Metrics => 1 db befektetés
# Cozi => 2 db befektetés
# Trusera => 1 db befektetés
# Alerts.com => 1 db befektetés
# Myrio => 1 db befektetés
# Grid Networks => 2 db befektetés
#
#
# A legtöbb befektetést a Facebook cégnél tették, összesen 495700000

# %%
get_inv_by_categ(investments)
# Out:
# web => 11753474750
# software => 1017942000
# hardware => 824500000
# mobile => 323020000
# cleantech => 258900000
# other => 119850000
# biotech => 77250000
# consulting => 32135000
